# %% [markdown]
# <center><img src="images/header.png"></center>
#
# <h1><center>Алгоритмы интеллектуальной обработки больших объемов данных</center></h1>
# <hr>
# <h2><center>SVM, Kernel Trick (практика)</center></h2>

# %% [markdown]
# **Срок сдачи:** 24 апреля 2017, 06:00 <br>
# **Штраф за опоздание:** -2 балла после 06:00 24 апреля, -4 балла после 06:00 1 мая, -6 баллов после 06:00 8 мая
#
# При отправлении ДЗ указывайте фамилию в названии файла<br>
#
# Не забудте создать задание в Slack через /todo.
#
# Используйте данный Ipython Notebook при оформлении домашнего задания.

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tqdm import tqdm_notebook
from sklearn.svm import SVR
from sklearn.svm import SVC
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import StandardScaler

# %matplotlib inline

plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (12, 6)

# %% [markdown]
# # Семинарская часть

# %% [markdown]
# Функция `select_model` принимает на вход обучающую выборку и возвращает модель (машину опорных векторов) с наилучшими параметрами для данной выборки. Эту функцию нужно реализовать.
#
# Подбираемые параметры подели включают в себя:
# - различные функции ядра (линейное, RBF, полиномиальные разных степеней)
# - различные значения константы $C$ ($0, 0.1, 1, 10, 100, 1000, 10000$)
#
# Подбирать параметры необходимо с помощью 10-fold кросс-валидации. Сейчас в качестве заглушки функция всегда возвращает линейный SVC.

# %%
def select_model(x, y):
    """
    Implement some model selection strategy here:
    seek through different kernels and parameters.

    Use a validation scheme to select the best model
    
    Quality metric: accuracy

    Returns:
        SVM classifier implemented by sklearn SVC class.
    """
    best_accuracy = 0
    best_model = None
    
    kernel = ['linear', 'poly', 'rbf', 'sigmoid']
    constant = [0.1, 1, 100, 1000, 10000]

    for ker in kernel:
        for c in constant:
            if(ker == 'poly'):
                for deg in xrange(2, 4):
                    model = SVC(kernel=ker, C=c, degree=deg)
                    print "Trying model {}".format(model)
                    accuracy = np.mean(cross_val_score(model, x, y, cv=10, n_jobs=-1))
                    if(accuracy > best_accuracy):
                        best_model = model
                        best_accuracy = accuracy 
            else:
                model = SVC(kernel=ker, C=c)
                print "Trying model {}".format(model)
                accuracy = np.mean(cross_val_score(model, x, y, cv=10, n_jobs=-1))
                if(accuracy > best_accuracy):
                    best_model = model
                    best_accuracy = accuracy
            
    best_model.fit(x, y)
    print "Best model %s, with accuracy %f" % (best_model, best_accuracy)
    return best_model

# %% [markdown]
# Далее две вспомогательные функции, которые отображают данные и разделяющую поверхность

# %%
def plot_data_set(x, y, description=''):
    print "Plotting data set points"
    plt.figure(figsize=(8, 8))

    colors = np.array(['r', 'b'])[y]
    plt.title(description, fontsize='small')
    plt.scatter(x[:, 0], x[:, 1], marker='o', c=colors, s=50)
    
def plot_decision_region(x1_min, x2_min, x1_max, x2_max, clf, n_points=1000):
    print "Plotting decision region"
    x1, x2 = np.meshgrid(np.linspace(x1_min, x1_max, n_points), np.linspace(x2_min, x2_max, n_points))
    z = clf.decision_function(np.c_[x1.ravel(), x2.ravel()]).reshape(x1.shape)

    plt.contour(x1, x2, z, levels=[0.0], linestyles='solid', linewidths=2.0)
    plt.contour(x1, x2, z, levels=[-1.0, 1.0], linestyles='dashed', linewidths=1.0)

# %%
def generate_linear(size=100, k=1.1, b=0.0, nl=0.1):
    print "Generating 'Linearly-separated' data set"

    x = np.random.random((size, 2))
    y = np.zeros(size, dtype=int)
    noise = np.random.randn(size) * nl
    y[x[:, 1] - (k * x[:, 0] + b) > noise] = 1

    return x, y

x, y = generate_linear()
clf = select_model(x, y)
plot_data_set(x, y)
plot_decision_region(x[:, 0].min(), x[:, 1].min(), x[:, 0].max(), x[:, 1].max(), clf)
# Out:
# Generating 'Linearly-separated' data set
# Trying model SVC(C=0.1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# Trying model SVC(C=1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# Trying model SVC(C=100, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# Trying model SVC(C=1000, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# Trying model SVC(C=10000, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# Trying model SVC(C=0.1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=2, gamma='auto', kernel='poly',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# Trying model SVC(C=0.1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='poly',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# Trying model SVC(C=1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=2, gamma='auto', kernel='poly',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# Trying model SVC(C=1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='poly',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# Trying model SVC(C=100, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=2, gamma='auto', kernel='poly',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# Trying model SVC(C=100, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='poly',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# Trying model SVC(C=1000, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=2, gamma='auto', kernel='poly',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# Trying model SVC(C=1000, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='poly',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# Trying model SVC(C=10000, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=2, gamma='auto', kernel='poly',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# Trying model SVC(C=10000, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='poly',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# Trying model SVC(C=0.1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# Trying model SVC(C=1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# Trying model SVC(C=100, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# Trying model SVC(C=1000, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# Trying model SVC(C=10000, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# Trying model SVC(C=0.1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='sigmoid',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# Trying model SVC(C=1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='sigmoid',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# Trying model SVC(C=100, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='sigmoid',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# Trying model SVC(C=1000, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='sigmoid',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# Trying model SVC(C=10000, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='sigmoid',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# Best model SVC(C=100, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False), with accuracy 0.914343
# Plotting data set points
# Plotting decision region

# %%
def generate_concentric(size=100, r1=1.0, r2=2.0, sigma=0.3):
    print "Generating 'Concentric circles' data set"
    x = np.zeros((size, 2))
    x[:size/2, 0] = sigma * np.random.randn(size/2) + r1
    x[size/2:, 0] = sigma * np.random.randn(size/2) + r2
    x[:, 1] = (np.random.random(size) - 0.5) * 2 * np.pi
    y = np.hstack([np.zeros(size/2, dtype=int), np.ones(size/2, dtype=int)])

    z = np.zeros((size, 2))
    z[:, 0] = x[:, 0] * np.cos(x[:, 1])
    z[:, 1] = x[:, 0] * np.sin(x[:, 1])

    return z, y

x, y = generate_concentric()
clf = select_model(x, y)
plot_data_set(x, y)
plot_decision_region(x[:, 0].min(), x[:, 1].min(), x[:, 0].max(), x[:, 1].max(), clf)
# Out:
# Generating 'Concentric circles' data set
# Trying model SVC(C=0.1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# Trying model SVC(C=1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# Trying model SVC(C=100, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# Trying model SVC(C=1000, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# Trying model SVC(C=10000, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# Trying model SVC(C=0.1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=2, gamma='auto', kernel='poly',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# Trying model SVC(C=0.1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='poly',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# Trying model SVC(C=1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=2, gamma='auto', kernel='poly',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# Trying model SVC(C=1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='poly',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# Trying model SVC(C=100, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=2, gamma='auto', kernel='poly',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# Trying model SVC(C=100, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='poly',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# Trying model SVC(C=1000, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=2, gamma='auto', kernel='poly',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# Trying model SVC(C=1000, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='poly',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# Trying model SVC(C=10000, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=2, gamma='auto', kernel='poly',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# Trying model SVC(C=10000, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='poly',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# Trying model SVC(C=0.1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# Trying model SVC(C=1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# Trying model SVC(C=100, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# Trying model SVC(C=1000, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# Trying model SVC(C=10000, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# Trying model SVC(C=0.1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='sigmoid',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# Trying model SVC(C=1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='sigmoid',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# Trying model SVC(C=100, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='sigmoid',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# Trying model SVC(C=1000, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='sigmoid',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# Trying model SVC(C=10000, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='sigmoid',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# Best model SVC(C=0.1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=2, gamma='auto', kernel='poly',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False), with accuracy 0.920000
# Plotting data set points
# Plotting decision region

# %%
def generate_sin(size=200):
    print "Generating 'Sinus-separated' data set"

    x = np.random.random((size, 2))
    x[:, 0] = x[:, 0] * 4 * np.pi
    x[:, 1] = (x[:, 1] - 0.5) * 2
    y = np.zeros(size, dtype=int)
    y[x[:, 1] > np.sin(x[:, 0])] = 1

    return x, y

x, y = generate_sin()
clf = select_model(x, y)
plot_data_set(x, y)
plot_decision_region(x[:, 0].min(), x[:, 1].min(), x[:, 0].max(), x[:, 1].max(), clf)
# Out:
# Generating 'Sinus-separated' data set
# Trying model SVC(C=0.1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# Trying model SVC(C=1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# Trying model SVC(C=100, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# Trying model SVC(C=1000, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# Trying model SVC(C=10000, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# Trying model SVC(C=0.1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=2, gamma='auto', kernel='poly',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# Trying model SVC(C=0.1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='poly',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# Trying model SVC(C=1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=2, gamma='auto', kernel='poly',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# Trying model SVC(C=1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='poly',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# Trying model SVC(C=100, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=2, gamma='auto', kernel='poly',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# Trying model SVC(C=100, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='poly',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# Trying model SVC(C=1000, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=2, gamma='auto', kernel='poly',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# Trying model SVC(C=1000, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='poly',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# Trying model SVC(C=10000, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=2, gamma='auto', kernel='poly',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# Trying model SVC(C=10000, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='poly',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# Trying model SVC(C=0.1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# Trying model SVC(C=1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# Trying model SVC(C=100, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# Trying model SVC(C=1000, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# Trying model SVC(C=10000, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# Trying model SVC(C=0.1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='sigmoid',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# Trying model SVC(C=1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='sigmoid',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# Trying model SVC(C=100, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='sigmoid',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# Trying model SVC(C=1000, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='sigmoid',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# Trying model SVC(C=10000, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='sigmoid',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# Best model SVC(C=100, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False), with accuracy 0.949950
# Plotting data set points
# Plotting decision region

# %% [markdown]
# # Регрессия с SVM (3 балла)

# %% [markdown]
# Загрузите набор данных из *titanium.csv*<br/>
# Мы будем решать задачу восстановления столбца 'y' по столбцу 'x'.

# %% [markdown]
# ## Визуализация данных (1 балл)

# %% [markdown]
# Выполните стандартную предобработку данных (z-score) и выведите их на графике.

# %%
# Your Code Here
df = pd.read_csv('./titanium.csv')
df.head()
# Out:
#        x      y
# 0  585.0  0.644
# 1  595.0  0.622
# 2  605.0  0.638
# 3  615.0  0.649
# 4  625.0  0.652

# %%
Xy = df.values
Xy.shape
# Out:
# (49L, 2L)

# %%
scaler = StandardScaler()
Xy_norm = scaler.fit_transform(Xy)
plt.figure()
plt.plot(Xy_norm.T[0], Xy_norm.T[1])
plt.scatter(Xy_norm.T[0], Xy_norm.T[1], color='b')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# ## Обучение моделей (2 балла)

# %% [markdown]
# Рассмотрите 3 ядра:
# * Линейное
# * Полиномиальное (degree = 3, gamma = 6, coef0 = 1)
# * RBF (gamma = 6, coef0 = 1)
#
# Во всех случаях установить ширину трубки `epsilon=0.01`
#
# Для каждого из ядер:
# 1. Пусть `C = np.logspace(-2, 2, 10)`. Постройте графики зависимости ошибки от параметра $C$ (ось графика со значениями параметра $C$ должна быть в логарифмической шкале). Ошибка измеряется как средняя абсолютная ошибка.
# 2. Для наулучшего параметра $С$ каждого из ядер постройте график с данными и предстазанием по svm
#
# В каких случаях возникает эффекты недообучения, переобучения?

# %%
from sklearn.metrics import mean_absolute_error

# %%
kernel = ['linear', 'poly', 'rbf']
kernel.index('poly')
# Out:
# 1

# %%
## Your Code Here
def model_error(x, y):
    best_error = 1000.0
    best_c = 0.0
    
    kernel = ['linear', 'poly', 'rbf']
    Constant = np.logspace(-2, 2, 10)
    
    plt.figure(figsize=(12, 18))
    
    
    for ker in kernel:
        error = []
        for c in Constant:
            model = SVR(kernel=ker, C=c, degree=3, gamma=6, coef0=1, epsilon=0.01)
            model.fit(x, y)
            y_hat = model.predict(x)
            err = mean_absolute_error(y, y_hat)
            error.append(err)
            if(err < best_error):
                    best_error = err
                    best_c = c
        print 'Kernel = %s; Best C = %f' %(ker, best_c)
        plt.subplot(3, 1, kernel.index(ker)+1)
        plt.plot(Constant, error)
        plt.xscale('log')
        plt.xlabel('C')
        plt.ylabel('MeanAbsoluteError')
        plt.title('$Kernel= {}$'.format(ker))

# %%
x, y = np.reshape(Xy_norm.T[0], (Xy_norm.T[0].shape[0], 1)), np.reshape(Xy_norm.T[1], (Xy_norm.T[1].shape[0], 1))

model_error(x, y.ravel())
# Out:
# Kernel = linear; Best C = 0.010000
# Kernel = poly; Best C = 0.010000
# Kernel = rbf; Best C = 100.000000

# %% [markdown]
# Похоже на переобучение в случае rbf

# %%
def plot_SVR(x, y, z, description=''):
    print "Plotting data set points"
    plt.figure(figsize=(8, 8))
    plt.title(description)
    plt.scatter(x, y, marker='o', s=50)
    plt.plot(x, z, c='b')
    plt.xlabel('x')
    plt.ylabel('y')

# %%
kernel = {'linear': 0.01, 'poly': 0.01, 'rbf': 100.0}
for ker in kernel:
    model = SVR(kernel=ker, C=kernel[ker], degree=3, gamma=6, coef0=1, epsilon=0.01)
    model.fit(x, y.ravel())
    z = model.predict(x)
    plot_SVR(x, y, z, '$Kernel = '+ker+'; C = '+str(kernel[ker])+'$')
# Out:
# Plotting data set points
# Plotting data set points
# Plotting data set points

# %% [markdown]
# # Определение языка слова (7 баллов)

# %% [markdown]
# В данном задании вам необходимо определить, на каком языке написано слово.
#
# Вам будет дано два текста - первые предложения произведения "Война и Мир" на английком и испанском, разбитые на слова. У слов нет общепринятого числового представления, поэтому мы предлагаем вам реализовать собственноге ядро для SVM, основанное на редакторском расстоянии или [расстоянии Левинштейна](https://ru.wikipedia.org/wiki/%D0%A0%D0%B0%D1%81%D1%81%D1%82%D0%BE%D1%8F%D0%BD%D0%B8%D0%B5_%D0%9B%D0%B5%D0%B2%D0%B5%D0%BD%D1%88%D1%82%D0%B5%D0%B9%D0%BD%D0%B0).
#
# Имплементировать расстояние Леванштейна не нужно - можно взять любую доступную реализацию, например [здесь](https://github.com/toastdriven/pylev) или [здесь](https://github.com/ztane/python-Levenshtein).

# %% [markdown]
# ## Загрузка (1 балл)
#
# Загрузите данные из файлов *war_and_peace_es.txt* и *war_and_peace_en.txt*.<br/>
# В результате вы должны получить pandas.DataFrame со столбцами *index* | *word* | *label*, где *index* - это индекс pandas, *word* - это слово и *label* - это метка класса (0 или 1)

# %%
## Your Code Here
df1 = pd.read_csv('./war_and_peace_en.txt', header=None, names=['Word'])
df1['Label'] = np.zeros(len(df1.index), dtype=int)
df2 = pd.read_csv('./war_and_peace_es.txt', header=None, names=['Word'])
df2['Label'] = np.ones(len(df2.index), dtype=int)
df = pd.concat([df1, df2], ignore_index=True)
df.head()
# Out:
#       Word  Label
# 0      war      0
# 1      and      0
# 2    peace      0
# 3      leo      0
# 4  tolstoy      0

# %% [markdown]
# ## Подготовка данных (2 балла)
#
# Особенностью пользовательского ядра в sklean.SVC является то, что на вход оно должно принимать именно вектора чисел.<br/>
# В нашем случае это будут индексы соответствующих слов из корпуса. То есть вместо вектора ['treat', 'celebrit', 'prince', ...] на вход в ядро подается вектор из индексов [9209, 11145, 7735, ...] с помощью которых вы будете находить сами слова.
#
# Прежде чем мы начнем строить ядро, надо подготовить данные. Для этого:
# 1. Задайте переменную RND_SEED, которая будет использоваться в любых генераторах случайных чисел в вашем коде (обычно параметр "random_seed")
# 2. Случайным образом перемешайте и заново проиндексируйте таблицу, полученную выше (используйте методы df.sample() и df.reset_index())
# 3. Ядро может вычисляться достаточно долго, поэтому можете урезать таблицу, но оставить в ней не менее 1000 слов.
# 4. Разбейте данные на обучающую и контрольную выборку в пропорции 60/40
#
# В результате вы должны получить вектор-столбец X_train, X_test с **индексами** слов и векторы y_train, y_test с метками классов.

# %%
from sklearn.cross_validation import train_test_split

# %%
RND_SEED = 0
df = df.sample(frac=1, random_state=RND_SEED)
df.reset_index(inplace=True, drop=True)
df.head()
# Out:
#        Word  Label
# 0     tutte      1
# 1     comme      1
# 2       non      1
# 3       and      0
# 4  anecdote      1

# %%
df_short = df.loc[:1999,:]
print(len(df_short.index))
# Out:
# 2000

# %%
Train, Test = train_test_split(df_short, train_size=0.60, random_state=RND_SEED)
X_train, y_train = Train.index.values, Train['Label'].values
X_test, y_test = Test.index.values, Test['Label'].values

# %% [markdown]
# ## Расчет ядра (3 балла)
#
# Некоторые указания по составлению пользовательского ядра можно найти [здесь](http://stackoverflow.com/questions/26962159/how-to-use-a-custom-svm-kernel).
#
# Если в двух словах:<br/>
# Функция, реазлизующая расчет ядра должна принимать две матрицы $U$ и $V$ с признаковым описанием объектов (во време обучения они обе относятся к обучающей выборке, а во время применения - одна матрица относится к обучающей выборке, а другая к контрольной).
#
# В результате, функция должна возвращать матрицу ядра $G_{ij} = K(U_i, V_j)$.
#
# Таким образом, в этом задании вам надо:
# 1. Написать функцию *string_kernel(U, V)*, расчитывающее матрицу ядра $G_{ij}$
# 2. Визуализировать матрицу только для обучающей выборки (функция plt.imshow()).
#
# **ВАЖНО**<br/>
# На лекции мы рассмотрели, что ядро должно обладать определенными свойствами, поэтому не получится рассчитать $G_{ij}$ как расстояние Левинштейна между словами $\text{word}_i$ и $\text{word}_j$.<br/>
# Вместо этого используйте какое-нибудь готовое ядро, зависящее от расстояние между объектами.

# %%
import pylev

# %%
def string_kernel(U, V):
    #Your Code Here
    G = np.zeros((U.shape[0], V.shape[0]))
    Distances = np.zeros((U.shape[0], V.shape[0]))
    sigma = 4.0
    for i, x in enumerate(U):
        for j, y in enumerate(V):
            Distances[i, j] = pylev.levenshtein(str(df.loc[U[i], 'Word']), str(df.loc[V[j], 'Word']))
    G = np.exp(-Distances**2/sigma**2)
    return G

# %%
G = string_kernel(X_train, X_train)
G1 = string_kernel(X_test, X_train)
plt.imshow(G)

# %% [markdown]
# ## Оценка качества (1 балл)
#
# Обучите метод опорных векторов с различными значениями параметра штрафа $C$.<br/>
# Для каждого значения выведите accuracy на обучащюей и контрольной выборке.
#
# Постарайтесь достичь качества в 70% на тестовой выборке

# %%
from sklearn.metrics import accuracy_score

# %%
# Your Code Here
def select_C(G, G1, y_train, y_test):
    best_accuracy = 0
    best_model = None
    Constant = np.logspace(-2, 2, 20)
    for c in Constant:
        model = SVC(kernel='precomputed', C=c, random_state=RND_SEED)
        print "Trying model {}".format(model)
        model.fit(G, y_train)
        train_accuracy = accuracy_score(y_train, model.predict(G))
        test_accuracy = accuracy_score(y_test, model.predict(G1))
        print "Train data accuracy = %f" %train_accuracy
        print "Test data accuracy = %f" %test_accuracy
        print"============================================================================================"
        if(test_accuracy > best_accuracy):
            best_model = model
            best_accuracy = test_accuracy 
            
    best_model.fit(G, y_train)
    print "Best model %s, with accuracy %f" % (best_model, best_accuracy)
    return best_model

# %%
clf = select_C(G, G1, y_train, y_test)
# Out:
# Trying model SVC(C=0.01, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto',
#   kernel='precomputed', max_iter=-1, probability=False, random_state=0,
#   shrinking=True, tol=0.001, verbose=False)
# Train data accuracy = 0.566667
# Test data accuracy = 0.576250
# ============================================================================================
# Trying model SVC(C=0.016237767391887217, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto',
#   kernel='precomputed', max_iter=-1, probability=False, random_state=0,
#   shrinking=True, tol=0.001, verbose=False)
# Train data accuracy = 0.566667
# Test data accuracy = 0.576250
# ============================================================================================
# Trying model SVC(C=0.026366508987303583, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto',
#   kernel='precomputed', max_iter=-1, probability=False, random_state=0,
#   shrinking=True, tol=0.001, verbose=False)
# Train data accuracy = 0.680000
# Test data accuracy = 0.676250
# ============================================================================================
# Trying model SVC(C=0.042813323987193938, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto',
#   kernel='precomputed', max_iter=-1, probability=False, random_state=0,
#   shrinking=True, tol=0.001, verbose=False)
# Train data accuracy = 0.732500
# Test data accuracy = 0.711250
# ============================================================================================
# Trying model SVC(C=0.069519279617756058, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto',
#   kernel='precomputed', max_iter=-1, probability=False, random_state=0,
#   shrinking=True, tol=0.001, verbose=False)
# Train data accuracy = 0.754167
# Test data accuracy = 0.738750
# ============================================================================================
# Trying model SVC(C=0.11288378916846889, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto',
#   kernel='precomputed', max_iter=-1, probability=False, random_state=0,
#   shrinking=True, tol=0.001, verbose=False)
# Train data accuracy = 0.788333
# Test data accuracy = 0.768750
# ============================================================================================
# Trying model SVC(C=0.18329807108324356, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto',
#   kernel='precomputed', max_iter=-1, probability=False, random_state=0,
#   shrinking=True, tol=0.001, verbose=False)
# Train data accuracy = 0.785000
# Test data accuracy = 0.760000
# ============================================================================================
# Trying model SVC(C=0.29763514416313175, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto',
#   kernel='precomputed', max_iter=-1, probability=False, random_state=0,
#   shrinking=True, tol=0.001, verbose=False)
# Train data accuracy = 0.781667
# Test data accuracy = 0.753750
# ============================================================================================
# Trying model SVC(C=0.48329302385717521, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto',
#   kernel='precomputed', max_iter=-1, probability=False, random_state=0,
#   shrinking=True, tol=0.001, verbose=False)
# Train data accuracy = 0.797500
# Test data accuracy = 0.758750
# ============================================================================================
# Trying model SVC(C=0.78475997035146106, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto',
#   kernel='precomputed', max_iter=-1, probability=False, random_state=0,
#   shrinking=True, tol=0.001, verbose=False)
# Train data accuracy = 0.778333
# Test data accuracy = 0.775000
# ============================================================================================
# Trying model SVC(C=1.2742749857031335, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto',
#   kernel='precomputed', max_iter=-1, probability=False, random_state=0,
#   shrinking=True, tol=0.001, verbose=False)
# Train data accuracy = 0.764167
# Test data accuracy = 0.768750
# ============================================================================================
# Trying model SVC(C=2.0691380811147901, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto',
#   kernel='precomputed', max_iter=-1, probability=False, random_state=0,
#   shrinking=True, tol=0.001, verbose=False)
# Train data accuracy = 0.761667
# Test data accuracy = 0.766250
# ============================================================================================
# Trying model SVC(C=3.3598182862837809, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto',
#   kernel='precomputed', max_iter=-1, probability=False, random_state=0,
#   shrinking=True, tol=0.001, verbose=False)
# Train data accuracy = 0.755833
# Test data accuracy = 0.752500
# ============================================================================================
# Trying model SVC(C=5.4555947811685144, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto',
#   kernel='precomputed', max_iter=-1, probability=False, random_state=0,
#   shrinking=True, tol=0.001, verbose=False)
# Train data accuracy = 0.766667
# Test data accuracy = 0.732500
# ============================================================================================
# Trying model SVC(C=8.8586679041008232, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto',
#   kernel='precomputed', max_iter=-1, probability=False, random_state=0,
#   shrinking=True, tol=0.001, verbose=False)
# Train data accuracy = 0.760833
# Test data accuracy = 0.725000
# ============================================================================================
# Trying model SVC(C=14.384498882876629, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto',
#   kernel='precomputed', max_iter=-1, probability=False, random_state=0,
#   shrinking=True, tol=0.001, verbose=False)
# Train data accuracy = 0.757500
# Test data accuracy = 0.688750
# ============================================================================================
# Trying model SVC(C=23.357214690901213, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto',
#   kernel='precomputed', max_iter=-1, probability=False, random_state=0,
#   shrinking=True, tol=0.001, verbose=False)
# Train data accuracy = 0.755000
# Test data accuracy = 0.686250
# ============================================================================================
# Trying model SVC(C=37.92690190732246, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto',
#   kernel='precomputed', max_iter=-1, probability=False, random_state=0,
#   shrinking=True, tol=0.001, verbose=False)
# Train data accuracy = 0.758333
# Test data accuracy = 0.682500
# ============================================================================================
# Trying model SVC(C=61.584821106602604, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto',
#   kernel='precomputed', max_iter=-1, probability=False, random_state=0,
#   shrinking=True, tol=0.001, verbose=False)
# Train data accuracy = 0.767500
# Test data accuracy = 0.745000
# ============================================================================================
# Trying model SVC(C=100.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto',
#   kernel='precomputed', max_iter=-1, probability=False, random_state=0,
#   shrinking=True, tol=0.001, verbose=False)
# Train data accuracy = 0.766667
# Test data accuracy = 0.723750
# ============================================================================================
# Best model SVC(C=0.78475997035146106, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto',
#   kernel='precomputed', max_iter=-1, probability=False, random_state=0,
#   shrinking=True, tol=0.001, verbose=False), with accuracy 0.775000

# %%
print "Score = %f" %accuracy_score(y_test, clf.predict(G1))
# Out:
# Score = 0.775000
